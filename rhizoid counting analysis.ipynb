# %%
import pandas as pd
import numpy as np
import scipy as sp

# %%
cd c:\Users\Admin\Downloads\
# Out:
# c:\Users\Admin\Downloads

# %%
rhizoid_data = pd.read_excel("rhizoid counting.xlsx")
rhizoid_data
# Out:
#        line  sample  number of rhizoids
# 0   SpKD1 H       0                  18
# 1   SpKD1 H       1                  20
# 2   SpKD1 H       2                  21
# 3   SpKD1 H       3                  17
# 4   SpKD1 H       4                  30
# 5   SpKD1 H       5                  25
# 6   SpKD1 H       6                  25
# 7   SpKD1 H       7                  18
# 8   SpKD1 H       8                  20
# 9   SpKD1 H       9                  32
# 10  MpSg9 G       0                   0
# 11  MpSg9 G       1                   0
# 12  MpSg9 G       2                   0
# 13  MpSg9 G       3                   0
# 14  MpSg9 G       4                   0
# 15  MpSg9 B       0                   6
# 16  MpSg9 B       1                   4
# 17  MpSg9 B       2                  18
# 18  MpSg9 B       3                   0
# 19  MpSg9 B       4                   0
# 20  SpKD1 G       0                  16
# 21  SpKD1 G       1                  25
# ...

# %%
SpKD1_H= rhizoid_data[rhizoid_data.line == "SpKD1 H"]
print SpKD1_H
# Out:
#       line  sample  number of rhizoids
# 0  SpKD1 H       0                  18
# 1  SpKD1 H       1                  20
# 2  SpKD1 H       2                  21
# 3  SpKD1 H       3                  17
# 4  SpKD1 H       4                  30
# 5  SpKD1 H       5                  25
# 6  SpKD1 H       6                  25
# 7  SpKD1 H       7                  18
# 8  SpKD1 H       8                  20
# 9  SpKD1 H       9                  32

# %%
Lines = rhizoid_data.line
Lines = Lines.values
Lines = set(Lines)

# %%
for line_name in Lines:
    line_name = rhizoid_data[rhizoid_data.line == str(line_name)]
    print line_name
# Out:
#        line  sample  number of rhizoids
# 30  SpKD1 A       0                   0
# 31  SpKD1 A       1                   9
# 32  SpKD1 A       2                   0
# 33  SpKD1 A       3                   1
# 34  SpKD1 A       4                   0
#        line  sample  number of rhizoids
# 15  MpSg9 B       0                   6
# 16  MpSg9 B       1                   4
# 17  MpSg9 B       2                  18
# 18  MpSg9 B       3                   0
# 19  MpSg9 B       4                   0
#       line  sample  number of rhizoids
# 35  MpSg9A       0                  11
# 36  MpSg9A       1                   1
# 37  MpSg9A       2                   0
# 38  MpSg9A       3                   0
# 39  MpSg9A       4                   0
#        line  sample  number of rhizoids
# 10  MpSg9 G       0                   0
# 11  MpSg9 G       1                   0
# 12  MpSg9 G       2                   0
# 13  MpSg9 G       3                   0
# ...

# %%
# Out:
#   File "<ipython-input-98-e67e65b3a0b4>", line 1
#     MpSg9 D
#           ^
# SyntaxError: invalid syntax
