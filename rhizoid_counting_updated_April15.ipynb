# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
cd C:\Users\Admin\Dropbox\Postgrad\Research\Basal Land Plants\Marchantia\Transformation\Summary of data for analysis April 2015\Rhizoid counting
# Out:
# C:\Users\Admin\Dropbox\Postgrad\Research\Basal Land Plants\Marchantia\Transformation\Summary of data for analysis April 2015\Rhizoid counting

# %%
rhizoid_data = pd.read_csv("rhizoid counting combined.csv")

# %%
colors = ["#4C72B0", "#4C72B0", "#4C72B0", "#4C72B0","#4C72B0","#55A868","#55A868","#64B5CD","#64B5CD","#64B5CD","#64B5CD","#64B5CD","#7CC193","#7CC193","#7CC193","#C44E52"]
x = sns.boxplot(rhizoid_data["number"],rhizoid_data["line"], color=colors)
plt.xticks(rotation=50)
#plt.savefig("C:/Users/Admin/Dropbox/Postgrad/Thesis/Subdocuments/Chapter 7. Marchantia knock-down and expression/Figures/all_rhizoid_box.png", dpi=1200)

# %%
colors2 = ["#4C72B0", "#4C72B0", "#4C72B0", "#4C72B0","#4C72B0","#55A868","#55A868","#C44E52"]
ch_6_data= rhizoid_data[~rhizoid_data["Treatment"].isin(["EFKD","35SKD"])]
x = sns.boxplot(ch_6_data["number"],ch_6_data["line"], color=colors2)
plt.xticks(rotation=50)
#plt.savefig("C:/Users/Admin/Dropbox/Postgrad/Thesis/Subdocuments/Chapter 6. Marchantia subgroup 9 overexpression/Figures/rhizoid_box.png", dpi=1200)
